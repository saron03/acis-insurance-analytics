# %%
import pandas as pd

# Load data
df = pd.read_csv('../data/MachineLearningRating_v3.csv', sep='|')

# Preview first few rows
df.head()
# Out:
# C:\Users\saron\AppData\Local\Temp\ipykernel_11452\1080050829.py:4: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/MachineLearningRating_v3.csv', sep='|')
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# ...

# %%
# Check shape
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")

# Check column types
df.info()

# Check a quick summary of numeric data
df.describe().T
# Out:
# Rows: 1000098, Columns: 52
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
# ...

# %%
# Check missing values
df.isnull().sum().sort_values(ascending=False)
# Out:
# NumberOfVehiclesInFleet     1000098
# CrossBorder                  999400
# CustomValueEstimate          779642
# Rebuilt                      641901
# Converted                    641901
# WrittenOff                   641901
# NewVehicle                   153295
# Bank                         145961
# AccountType                   40232
# Gender                         9536
# MaritalStatus                  8259
# VehicleType                     552
# make                            552
# mmcode                          552
# Model                           552
# Cylinders                       552
# bodytype                        552
# kilowatts                       552
# NumberOfDoors                   552
# VehicleIntroDate                552
# cubiccapacity                   552
# CapitalOutstanding                2
# SubCrestaZone                     0
# ItemType                          0
# Province                          0
# Country                           0
# ...

# %%
import pandas as pd

# Load the original data
df = pd.read_csv("../data/MachineLearningRating_v3.csv", sep='|')

# Optional: drop empty columns or rows with too many missing values (basic cleaning)
df = df.dropna(how="all", axis=1)  # drop completely empty columns
df = df.dropna(how="all", axis=0)  # drop completely empty rows

# Save as cleaned_data.csv
df.to_csv("cleaned_data.csv", index=False)

print("cleaned_data.csv created successfully!")
# Out:
# C:\Users\saron\AppData\Local\Temp\ipykernel_11452\1891975636.py:4: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/MachineLearningRating_v3.csv", sep='|')
# cleaned_data.csv created successfully!

# %%
df = pd.read_csv("cleaned_data.csv")
# Out:
# C:\Users\saron\AppData\Local\Temp\ipykernel_11452\1989269044.py:1: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("cleaned_data.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure()
sns.histplot(df['TotalPremium'], bins=30, kde=True)
plt.title("Distribution of TotalPremium")
plt.xlabel("TotalPremium")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure()
sns.histplot(df['TotalClaims'], bins=30, kde=True)
plt.title("Distribution of TotalClaims")
plt.xlabel("TotalClaims")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure()
sns.histplot(df['CustomValueEstimate'], bins=30, kde=True)
plt.title("Distribution of CustomValueEstimate")
plt.xlabel("CustomValueEstimate")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure()
sns.countplot(data=df, x='Province', order=df['Province'].value_counts().index)
plt.title("Policy Count by Province")
plt.xticks(rotation=45)
plt.ylabel("Count")
plt.show()

# %%
plt.figure()
sns.countplot(data=df, x='Gender')
plt.title("Policy Count by Gender")
plt.ylabel("Count")
plt.show()

# %%
plt.figure()
sns.countplot(data=df, x='VehicleType', order=df['VehicleType'].value_counts().index)
plt.title("Policy Count by VehicleType")
plt.xticks(rotation=45)
plt.ylabel("Count")
plt.show()

# %%
# Select key numeric columns for correlation
numeric_cols = ['TotalPremium', 'TotalClaims', 'CustomValueEstimate']

# Calculate correlation matrix
corr_matrix = df[numeric_cols].corr()

print(corr_matrix)

# Visualize correlation matrix with heatmap
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix of Key Numeric Variables")
plt.show()
# Out:
#                      TotalPremium  TotalClaims  CustomValueEstimate
# TotalPremium             1.000000     0.121588             0.019965
# TotalClaims              0.121588     1.000000             0.000853
# CustomValueEstimate      0.019965     0.000853             1.000000

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='TotalPremium', y='TotalClaims')
plt.title("Scatter Plot of TotalClaims vs TotalPremium")
plt.xlabel("TotalPremium")
plt.ylabel("TotalClaims")
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=df, x='TotalPremium', y='TotalClaims', hue='Province', alpha=0.7)
plt.title("TotalClaims vs TotalPremium by Province")
plt.xlabel("TotalPremium")
plt.ylabel("TotalClaims")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='TotalPremium', y='TotalClaims', hue='Gender', alpha=0.7)
plt.title("TotalClaims vs TotalPremium by Gender")
plt.xlabel("TotalPremium")
plt.ylabel("TotalClaims")
plt.show()

# %%
df['TransactionMonth'] = pd.to_datetime(df['TransactionMonth'])

# %%
monthly_summary = df.groupby('TransactionMonth')[['TotalClaims', 'TotalPremium']].sum().reset_index()
monthly_summary.head()
# Out:
#   TransactionMonth   TotalClaims  TotalPremium
# 0       2013-10-01      0.000000    371.063512
# 1       2013-11-01  50585.078947  21307.467009
# 2       2013-12-01   9283.385965  42484.748888
# 3       2014-01-01  12436.859649  54085.196865
# 4       2014-02-01  62989.307018  60788.436470

# %%
plt.figure(figsize=(12,6))
plt.plot(monthly_summary['TransactionMonth'], monthly_summary['TotalClaims'], label='TotalClaims')
plt.plot(monthly_summary['TransactionMonth'], monthly_summary['TotalPremium'], label='TotalPremium')
plt.title('Total Claims and Total Premium Over Time')
plt.xlabel('Transaction Month')
plt.ylabel('Amount')
plt.legend()
plt.grid(True)
plt.show()

# %%
monthly_summary['LossRatio'] = monthly_summary['TotalClaims'] / monthly_summary['TotalPremium']
plt.figure(figsize=(12,6))
plt.plot(monthly_summary['TransactionMonth'], monthly_summary['LossRatio'], marker='o', color='purple')
plt.title('Monthly Loss Ratio Over Time')
plt.xlabel('Transaction Month')
plt.ylabel('Loss Ratio')
plt.grid(True)
plt.show()

# %%
vehicle_claims = df.groupby(['make', 'Model'])['TotalClaims'].sum().reset_index().sort_values(by='TotalClaims', ascending=False)
vehicle_claims.head(10)
# Out:
#               make                             Model   TotalClaims
# 321         TOYOTA         QUANTUM 2.7 SESFIKILE 16s  1.203750e+07
# 320         TOYOTA         QUANTUM 2.7 SESFIKILE 15s  1.151173e+07
# 319         TOYOTA         QUANTUM 2.7 SESFIKILE 14s  9.967764e+06
# 315         TOYOTA    QUANTUM 2.5 D-4D SESFIKILE 16s  7.733236e+06
# 308         TOYOTA             HiACE SUPER 16 F/Lift  3.275205e+06
# 305         TOYOTA                      HiACE SIYAYA  1.727756e+06
# 313         TOYOTA          QUANTUM 2.5 D-4D 14 SEAT  1.339541e+06
# 45             CMC                       AMANDLA 2.2  1.106007e+06
# 259         TOYOTA                     AVANZA 1.5 SX  1.089785e+06
# 179  MERCEDES-BENZ  SPRINTER 515 CDi HI-ROOF F/C P/V  8.874161e+05

# %%
top_10_vehicles = vehicle_claims.head(10)

plt.figure(figsize=(12,6))
sns.barplot(data=top_10_vehicles, x='TotalClaims', y='Model', hue='make', dodge=False)
plt.title('Top 10 Vehicle Models by Total Claims')
plt.xlabel('Total Claims')
plt.ylabel('Vehicle Model')
plt.show()

# %%
lowest_claims = vehicle_claims[vehicle_claims['TotalClaims'] > 0].tail(10)
lowest_claims
# Out:
#                                     make                           Model  \
# 201  MERCEDES-BENZ                           SPRINTER 519 CDI XL F/C P/V
# 211                               NISSAN  ALMERA 1.6 LUXURY A/T (H16/27)
# 157                        MERCEDES-BENZ        SPRINTER 308 CDI F/C C/C
# 180                        MERCEDES-BENZ    SPRINTER 518 CDI D/C F/C C/C
# 146                        MERCEDES-BENZ            C200K ESTATE CLASSIC
# 287                               TOYOTA                    COROLLA 140i
# 346  TOYOTA                                           COROLLA 1.6 ESTEEM
# 50                                  FIAT          DUCATO 2.3 JTD F/C C/C
# 47                                   CMC       SESBUYILE 2.5 TDi 16 SEAT
# 358                           VOLKSWAGEN                   CITI.COM 1.4i
#
#      TotalClaims
# 201  1317.929825
# 211  1225.000000
# 157  1140.350877
# 180  1140.350877
# 146   850.000000
# 287   850.000000
# 346   850.000000
# ...

# %%
plt.figure(figsize=(12,5))
sns.histplot(df['TotalPremium'], bins=50, kde=True)
plt.title('Distribution of Total Premium')
plt.xlabel('Total Premium')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(12,5))
sns.histplot(df['TotalClaims'], bins=50, kde=True)
plt.title('Distribution of Total Claims')
plt.xlabel('Total Claims')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df['TotalPremium'])
plt.title('Boxplot of Total Premium')
plt.show()

plt.figure(figsize=(10,5))
sns.boxplot(x=df['TotalClaims'])
plt.title('Boxplot of Total Claims')
plt.show()

# %%
# Convert TransactionMonth to datetime if not already
df['TransactionMonth'] = pd.to_datetime(df['TransactionMonth'])

# Aggregate total claims and premiums by month
monthly_trends = df.groupby('TransactionMonth')[['TotalClaims', 'TotalPremium']].sum().reset_index()

# Plot trends over time
plt.figure(figsize=(14,6))
sns.lineplot(data=monthly_trends, x='TransactionMonth', y='TotalClaims', label='Total Claims')
sns.lineplot(data=monthly_trends, x='TransactionMonth', y='TotalPremium', label='Total Premium')
plt.title('Monthly Total Claims and Premiums Over Time')
plt.xlabel('Month')
plt.ylabel('Amount')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# 1. Compute sums by Province
prov_summary = (
    df.groupby('Province')
      .agg(TotalClaims=('TotalClaims','sum'),
           TotalPremium=('TotalPremium','sum'))
      .assign(LossRatio=lambda x: x.TotalClaims / x.TotalPremium)
      .sort_values('LossRatio')
      .reset_index()
)

# 2. Display the table of loss ratios
print(prov_summary[['Province','LossRatio']])

# 3. Bar plot of Loss Ratio by Province
plt.figure(figsize=(10,6))
sns.barplot(data=prov_summary, x='LossRatio', y='Province',
            palette='viridis')
plt.title("Loss Ratio by Province")
plt.xlabel("Loss Ratio (TotalClaims / TotalPremium)")
plt.ylabel("Province")
plt.xlim(0, prov_summary.LossRatio.max()*1.1)
plt.show()
# Out:
#         Province  LossRatio
# 0  Northern Cape   0.282699
# 1   Eastern Cape   0.633813
# 2        Limpopo   0.661199
# 3     Free State   0.680758
# 4     Mpumalanga   0.720897
# 5     North West   0.790367
# 6   Western Cape   1.059472
# 7  KwaZulu-Natal   1.082693
# 8        Gauteng   1.222018
# C:\Users\saron\AppData\Local\Temp\ipykernel_11452\2553328808.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=prov_summary, x='LossRatio', y='Province',
